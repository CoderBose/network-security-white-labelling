# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer

# %%
df = pd.read_csv('/content/network-security-white-labelling/resources/walmart/walmart_smart_wifi_plugs_products_dataset.csv')

# %%
df = df[df['brand']!="None"]

# %%
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
stop_words = set(stopwords.words('english'))
stemmer = PorterStemmer()
def preprocess_text(text):
    tokens = word_tokenize(text.lower())
    tokens = [stemmer.stem(token) for token in tokens if token.isalnum() and token not in stop_words]
    return ' '.join(tokens)

df['processed_long_description'] = df['long_description'].apply(str).apply(preprocess_text)

# %%
aggregated_data = df.groupby('brand')['processed_long_description'].apply(lambda x: ' '.join(x)).reset_index()

# %%
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(aggregated_data['processed_long_description'])
num_clusters = 5
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
aggregated_data['cluster'] = kmeans.fit_predict(tfidf_matrix)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
for cluster_num in range(num_clusters):
    print(f"Cluster {cluster_num + 1}:")
    print(aggregated_data[aggregated_data['cluster'] == cluster_num]['brand'].tolist())
    print()
# Out:
# Cluster 1:
# ['AIDAITOP', 'Ahomtoey', 'Aizhiyi', 'AliExpress', 'Amzer', 'Aokid', 'Aousin', 'Augper', 'Ausyst', 'BAMILL', 'BOOST', 'Beforeyayn', 'Bestonzon', 'Biekopu', 'Binmer', 'Bla Current', 'Buyweek', 'CKPFZ', 'COFEST', 'Craftmade', 'Crtynell', 'Cuoff', 'Cwcwfhzh', 'D-Link', 'DEWENWILS', 'Daiosportswear', 'Dqueduo', 'Dsermall', 'EKOUSN', 'Eleanos', 'Emerson', 'Fanjie', 'Feit Electric', 'Fosmart', 'Frcolor', 'Frogued', 'Funicet', 'GLDZI', 'GLFILL', 'GNCC', 'Gabba Goods', 'Geektale', 'General Brand', 'Generic', 'Ghome Smart', 'Gymax', 'Gyouwnll', 'HIBRO', 'Haofy', 'Haykey', 'Henpk', 'HiSmartLife', 'Honrane', 'IVIEW', 'JPLZi', 'Jadeshay', 'Jocestyle', 'Jooan', 'Junrui', 'JustSave4U', 'KQJQS', 'Kiplyki', 'Kootion', 'Kotyreds', 'Kuluzego', 'LHCER', 'LILEI', 'LINGANZH', 'LINKSTYLE.LIFE', 'LIZEALUCKY', 'Lanfini', 'Leky', 'Leviton', 'Linksys', 'Liphom', 'Loopsun', 'Lulshou', 'Lumary', 'Mnjin', 'NOBRAND', 'NUOLUX', 'Nikou', 'OAVQHLG3B', 'Ocuhome', 'PODPLUG', 'PRINxy', 'PROXXI', 'Philips', 'Plomeria', 'Presto Plug', 'QiChan', 'QianMai', 'Qiiburr', 'Qisuw', 'RANMEI', 'RKZDSR', 'Retap', 'Revolo', 'RnemiTe-amo', 'SHENGXINY', 'Saudism', 'Soundwave', 'Srliya', 'Steady Clothing', 'Sulgyt', 'Surnice', 'TAGOLD', 'TEPSMF', 'TOTO', 'Taylongift', 'Tebru', 'Tloowy', 'Topumt', 'Toymytoy', 'Trjgtas', 'Uknown', 'VALSEEL', 'VANLOFE', 'VEAREAR', 'VERR', 'Vic Tool', 'Von', 'WJSXC', 'WNG', 'WQQZJJ', 'Wanyng', 'Weloille', 'Westinghouse', 'WiZ', 'Wo-Fusoul', 'Woods', 'YoLink', 'Yohome', 'Zainafacai', 'Zettaguard', 'Zmodo', 'amlbb', 'aoksee', 'dido', 'hoksml', 'luohegesijiyujiaoyukeji', 'unknown']
#
# Cluster 2:
# ['ALEXTREME', 'AUPERTO', 'Aduro', 'AlexTong', 'Altatac', 'Aoycocr', 'Avatar Controls', 'BN-LINK', 'BULYAXIA', 'Braum', 'BroadLink', 'CNLive', 'Canopy', 'Chenyu', 'Cync', 'DJKDJL', 'DPI/ GPX', 'DazHom', 'Diamond', 'ELEGRP', 'ESPULL', 'Ecoey', 'Elenxs', 'Elleryy', 'Enbrighten', 'Energizer', 'Etekcity', 'Eva logik', 'EverDirect', 'Feiona', 'Fosmon', 'Fugacal', 'Funnyfairye', 'Geeni', 'General Electric', 'Gisneze', 'Globe Electric', 'Gosund', 'Growment', 'HAPYTHDA', 'HBN', 'HEXINGMC', 'HXAZGSJA', 'Heldig', 'Ibright', 'JRabbit', 'JYNOFD', 'Jaspertronics', 'Jonathan Y', 'KSXGJ', 'KTMC', 'Kasa Smart', 'Kayannuo', 'KissDate', 'LTESDTRAW', 'Legrand', 'Lingouzi', 'MDHAND', 'Menrkoo', 'Merkury Smart', 'Meross', 'Minimanihoo', 'Minoston', 'Mobi Technologies Inc.', 'Mouind', 'Namotu', 'New Link', 'Nexx', 'Nexxt Solutions', 'Nooie', 'OOSSXX', 'ORA', 'Okeba', 'Ounamio', 'PanDaDa', 'Premium Plus', 'QTOCIO', 'Qucoqpe', 'REFOSS', 'RKSTN', 'Reiko Wireless', 'Ringshlar', 'Roku', 'Rosnek', 'SNAP INVENT', 'SOONHUA', 'SYZ3C', 'Satco', 'ShineKing', 'Sohindel', 'Suwhwea', 'SwitchBot', 'TEMU-ONLINE', 'TOPGREENER', 'TP-Link', 'TYNZEO', 'Tarmeek', 'The Power Wear', 'Topesel', 'TorchStar', 'Totowood', 'TureClos', 'Tzchesanchi', 'VRURC', 'Visionis', 'Vivitar', 'Vntub', 'VoltMore', 'WBM', 'WGGE', 'Wovte', 'Wyze', 'XYZ Sales', 'Xodo', 'YIYI GUO', 'Yucurem', 'Zhenbaotian', 'Zoomarlous', 'eco4life', 'iHome', 'iHseno', 'solacol']
#
# Cluster 3:
# ['6588', 'Abcelit', 'Aibecy', 'Alvage', 'Andoer', 'Anself', 'Apexeon', 'Belka', 'CNMF', 'Cacagoo', 'Carevas', 'Ccdes', 'Dcenta', 'Docooler', 'ESHOO', 'Eccomum', 'Ecoyyzn', 'Gupbes', 'Htovila', 'KKmoon', 'Kernelly', 'Ldyso', 'Lixada', 'Loewten', 'Meterk', 'Moobody', 'Nebublu', 'Owsoo', 'PATIO_PEACE_INC', 'Shareland', 'Shinysix', 'Stibadium', 'TINYSOME', 'TOMSHOO', 'Tomfoto', 'Tomshine', 'Walmeck', 'YUUZONE', 'Yilbx', 'Zootealy', 'iMounTEK']
#
# Cluster 4:
# ['Amonsee', 'Ana', 'Anna', 'Aubess', 'Ceise', 'Center V', 'Clupup', 'Cogfs', 'Domqga', 'Dreamhall', 'Eleonora', 'Fancy', 'Farfi', 'Frehsky', 'Fule', 'Fyydes', 'Geege', 'Gerich', 'Girlsshop', 'HElectQRIN', 'Hadanceo', 'Hi、FANCY', 'LAFGUR', 'Leke', 'Liplasting', 'LuckyToU', 'Marbhall', 'Mduoduo', 'NUZYZ', 'Nomeni', 'Outfmvch', 'QIFEI', 'Ruibeauty', 'Sonoff', 'Sufanic', 'VASCWECD', 'Vakind & Device', 'Wanwan', 'Weekend', 'Worallymy', 'Xewsqmlo', 'Yannee', 'Ymiko', 'Zaqw', 'chenYun', 'enquiret']
#
# Cluster 5:
# ['BCLONG', 'BESHOM', 'BLUESON', 'BSTHOE', 'BTOER', 'BUYISI', 'Beisidaer', 'FALYEE', 'GDHOME', 'GLFSIL', 'GYZEE', 'Gnobogi', 'Goodhd', 'HALYEE', 'JINGT', 'JNANEEI', 'LIKEM', 'Lierteer', 'MANNYA', 'Mosiee', 'POPLIS', 'PhoneSoap', 'Purcolt', 'RAINB', 'Randolph', 'Rooha', 'SIEYIO', 'SUKIY', 'SUNFEX', 'Suyin', 'TIITSTOY', 'TRINGKY', 'TWIFER', 'VHUNT', 'Weflink', 'XEOVHVLJ', 'YIWEI', 'YLLSF', 'YaSaLy']

# %%
pca = PCA(n_components=2)
pca_result = pca.fit_transform(tfidf_matrix.toarray())

aggregated_data['pca_1'] = pca_result[:, 0]
aggregated_data['pca_2'] = pca_result[:, 1]

plt.figure(figsize=(10, 6))
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']

for cluster_num in range(num_clusters):
    cluster_data = aggregated_data[aggregated_data['cluster'] == cluster_num]
    plt.scatter(cluster_data['pca_1'], cluster_data['pca_2'], label=f'Cluster {cluster_num}', color=colors[cluster_num])

plt.title('Brand Clusters based on Long Descriptions')
plt.xlabel('PCA Dimension 1')
plt.ylabel('PCA Dimension 2')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Clustering using BERT

# %%
from transformers import BertTokenizer, BertModel
import torch


tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
model = BertModel.from_pretrained("bert-base-uncased")
# Out:
# tokenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]

# %%
tokenized_data = [tokenizer(text, padding=True, truncation=True, return_tensors="pt") for text in aggregated_data["processed_long_description"]]
embeddings = []

for item in tokenized_data:
    with torch.no_grad():
        output = model(**item)
        embeddings.append(output.last_hidden_state.mean(dim=1).squeeze().numpy())

num_clusters = 5
kmeans = KMeans(n_clusters=num_clusters)
cluster_labels = kmeans.fit_predict(embeddings)
aggregated_data["cluster_bert"] = cluster_labels
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
pca = PCA(n_components=2)
pca_result = pca.fit_transform(embeddings)

# Add PCA results to the DataFrame
aggregated_data['pca_1_bert'] = pca_result[:, 0]
aggregated_data['pca_2_bert'] = pca_result[:, 1]

plt.figure(figsize=(10, 6))
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']

for cluster_num in range(num_clusters):
    cluster_data = aggregated_data[aggregated_data['cluster_bert'] == cluster_num]
    plt.scatter(cluster_data['pca_1_bert'], cluster_data['pca_2_bert'], label=f'Cluster {cluster_num}', color=colors[cluster_num])

plt.title('Brand Clusters based on Long Descriptions (Bert)')
plt.xlabel('PCA Dimension 1')
plt.ylabel('PCA Dimension 2')
plt.legend()
plt.grid(True)
plt.show()
