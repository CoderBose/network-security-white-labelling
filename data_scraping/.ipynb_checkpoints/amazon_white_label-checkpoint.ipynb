# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
import requests
import re
from matplotlib import pyplot as plt
import time

# %%
def construct_url_params(url, kwargs):
    """
        Construct new url by adding query params to the url.
        
        Returns: new url
    """
    
    #if no query params add ? else add & at the end of url
    url+='?' if not '?' in url else '&'
    for i,j in kwargs.items():
        url+=f'{i}={j}&'
        
    #strip extra & at the end
    return url.rstrip('&')

# %%
construct_url_params("https://www.amazon.com/s?k=smart+plug+wifi", {'page': '2'})
# Out:
# 'https://www.amazon.com/s?k=smart+plug+wifi&page=2'

# %%
class AmazonScraper:
    base_url = "https://www.amazon.com/s?k="

    def __init__(self, product_name, chrome_path=r"C:\Users\moink\Downloads\chromedriver-win64\chromedriver.exe"):
        
        service = webdriver.chrome.service.Service(executable_path=chrome_path)
        options = webdriver.ChromeOptions()
        options.add_argument("--start-maximized")

        self.driver = webdriver.Chrome(service=service, options=options)

        self.search_url = self.base_url+ re.sub("\s+", "+", product_name)
        self.driver.get(self.search_url)
        
    
    def getProductURLList(self):
        WebDriverWait(self.driver, 20).until(EC.presence_of_element_located((By.XPATH, "//div[contains(@class, 'a-section a-spacing-none a-spacing-top-small s-title-instructions-style')]")))
        
        qid = self.driver.find_element(By.XPATH, "//input[@name='qid']").get_attribute("value")
        total_page = int(self.driver.find_element(By.XPATH, "//div[@role='navigation']").find_element(By.XPATH, "//span[contains(@class, 's-pagination-item s-pagination-disabled')]").text)

        product_urls = []
        
        curr_page = 1
        
        while True: 
            for product in self.driver.find_elements(By.XPATH, "//a[contains(@class, 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal')]"):
                product_urls.append(product.get_attribute("href"))


            curr_page +=1
            
            if curr_page > total_page:
                break

            next_page_url = construct_url_params(self.search_url, {'page': curr_page, 'qid': qid, 'ref': f'sr_pg_{curr_page}'})
            self.driver.get(next_page_url)
        
        return product_urls
    
    def getLeftImage(self):
        return [img.get_attribute('src') for img in scraper.driver.find_elements(By.XPATH, "//div[@id='imageBlock']//div[@class='imgTagWrapper']//img")]

    def parseCenterDiv(self):
        #parse centerDiv

        product_detail = {}
    #     required_div = ["featurebullets_feature_div", "bylineInfo_feature_div", "title_feature_div", "productOverview_feature_div"]
        centerDiv = self.driver.find_element(By.XPATH, "//div[@id='ppd' and div[@id='centerCol']]")

        #get product title
        product_detail['product_title'] = centerDiv.find_element(By.ID, 'productTitle').text

        #get product brand
        product_detail['product_brand'] = centerDiv.find_element(By.ID, 'bylineInfo').text
        product_detail['product_brand_url'] = centerDiv.find_element(By.ID, 'bylineInfo').get_attribute('href')

        #get prdouct overview
        product_detail['product_overview'] = {}
        for row in centerDiv.find_element(By.XPATH, "//div[@id='productOverview_feature_div']").find_elements(By.XPATH, "*//table//tr"):
            td = row.find_elements(By.TAG_NAME, 'td')
            product_detail['product_overview'][td[0].text] = td[1].text

        #parse about section
        #replace non ascii characters and continous spaces
        product_detail['product_about'] = re.sub("\s+", " ", re.sub(r'[^\x00-\x7F]+', "", centerDiv.find_element(By.XPATH, ".//div[@id='featurebullets_feature_div']//ul").text))


        return product_detail
    

    def parseBottomDivs(self):

        # parse div below ppd

        not_required_div = ["sims-themis-sponsored-products-2_feature_div","ask-btf_feature_div", "discovery-and-inspiration_feature_div","dp-ads-center-promo_feature_div", "ad-endcap-1_feature_div","btfSubNavDesktop_feature_div", "HLCXComparisonWidgetTechnical_feature_div", "legal-compliance-card_feature_div", "similarities_feature_div", "customer-reviews_feature_div", "va-related-videos-widget_feature_div"]

    #     essential_divs = ["detailBullets_feature_div", "aplusBrandStory_feature_div", "aplus_feature_div"]
        # Find the reference element
        reference_element = self.driver.find_element(By.XPATH, "//div[@id='bottomRow']")

        # Find all elements that come after the reference element
        following_elements = reference_element.find_elements(By.XPATH, "following-sibling::div[@data-feature-name and div and normalize-space()]")

        product_details = {}
        images = []
        for i, div in enumerate(following_elements): #.find_elements(By.XPATH, "//div[@data-feature-name and div]"):
            if div.get_attribute('id') not in not_required_div:
                print(i, div.get_attribute('id'))
                div_id = div.get_attribute('id')
                #parse table

#                 data = {}
#                 if div.find_elements(By.TAG_NAME, "table"):
#                     table = div.find_element(By.TAG_NAME, "table")
#                     for row in table.find_elements(By.TAG_NAME, 'tr'):
#                         tds = row.find_elements(By.TAG_NAME, 'td')

#                         data[tds[0]] = tds[1].strip()

#                 else:
#                     data = div.text

#                 #parse images
#                 images = [img.get_attribute('src') for img in div.find_elements(By.TAG_NAME, "img")]

#                 #either present, then include the div
#                 if data or images:
#                     product_details[div_id] = {'data': data, 'images': images}


                data = None
                if div.find_elements(By.TAG_NAME, "table"):
                    data = {}
                    table = div.find_element(By.TAG_NAME, "table")
                    for row in table.find_elements(By.TAG_NAME, 'tr'):
#                         tds = row.find_elements(By.TAG_NAME, 'td')
                        tds = row.find_elements(By.XPATH, ".//td | .//th")

                        data[tds[0].text] = tds[1].text.strip()

                else:
                    data = div.text


                #parse images
                images.extend([img.get_attribute('src') for img in div.find_elements(By.TAG_NAME, "img")])

                #either present, then include the div
                if data:
                    product_details[div_id] = data


        return product_details, images
        
                

    
    def quit(self):
        self.driver.quit()

# %%
scraper = AmazonScraper("smart plug wifi")

# %%
product_urls = scraper.getProductURLList()

# %%
len(product_urls)
# Out:
# 438

# %%
product_details= {}
for product_url in product_urls[:10]:
    print(product_url)
    scraper.driver.get(product_url)
    images = scraper.getLeftImage()
    product = scraper.parseCenterDiv()
    
    prod, img = scraper.parseBottomDivs()
    
    product.update(prod)
    images.extend(img)
    
    product_details[product['product_title']] = {'data': product, 'images': images}
# Out:
# https://www.amazon.com/sspa/click?ie=UTF8&spc=MTo2MDA4MTMyMTQ2MzQ2Njg4OjE3MDA0OTY3NzE6c3BfYXRmOjIwMDA2Njg0OTU1NTg2MTo6MDo6&url=%2FAmazon-smart-plug-works-with-Alexa%2Fdp%2FB089DR29T6%2Fref%3Dsr_1_1_ffob_sspa%3Fkeywords%3Dsmart%2Bwifi%2Bplugs%26qid%3D1700496771%26sr%3D8-1-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1
# 0 sac-btf-start_feature_div
# 1 device-dp-recommendations_feature_div
# 2 btfContent1_feature_div
# 3 btfContent5_feature_div
# 4 btfContent7_feature_div
# 5 btfContent8_feature_div
# 6 climatePledgeFriendlyBTF_feature_div
# https://www.amazon.com/sspa/click?ie=UTF8&spc=MTo2MDA4MTMyMTQ2MzQ2Njg4OjE3MDA0OTY3NzE6c3BfYXRmOjIwMDAxNjA0MTQ0MjY0MTo6MDo6&url=%2FBN-LINK-Monitoring-Function-Compatible-Assistant%2Fdp%2FB07CVPKD8Z%2Fref%3Dsr_1_2_sspa%3Fkeywords%3Dsmart%2Bwifi%2Bplugs%26qid%3D1700496771%26sr%3D8-2-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1
# 3 detailBullets_feature_div
# 4 buffetServiceCard_feature_div
# 5 productDescription_feature_div
# 6 importantInformation_feature_div
# 7 aplusBrandStory_feature_div
# 8 aplus_feature_div
# 10 productDocuments_feature_div
# https://www.amazon.com/sspa/click?ie=UTF8&spc=MTo2MDA4MTMyMTQ2MzQ2Njg4OjE3MDA0OTY3NzE6c3BfYXRmOjIwMDA2NzgxMTg0MDY5ODo6MDo6&url=%2FSONOFF-Monitoring-Certified-Assistant-Supporting%2Fdp%2FB0B2RBLKBY%2Fref%3Dsr_1_3_sspa%3Fkeywords%3Dsmart%2Bwifi%2Bplugs%26qid%3D1700496771%26sr%3D8-3-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1
# 3 buffetServiceCard_feature_div
# 4 aplusBrandStory_feature_div
# 5 aplus_feature_div
# 8 productDescription-3_feature_div
# 9 productDetailsNonPets_feature_div
# 10 productDocuments-2_feature_div
# 11 postsSameBrandCard_feature_div
# 13 importantInformation_feature_div
# https://www.amazon.com/TP-Link-Kasa-Smart-Wifi-Plug/dp/B07RCNB2L3/ref=sr_1_4?keywords=smart+wifi+plugs&qid=1700496771&sr=8-4
# 3 buffetServiceCard_feature_div
# 4 aplusBrandStory_feature_div
# 5 aplus_feature_div
# 8 productDescription-3_feature_div
# 9 productDetailsNonPets_feature_div
# 10 productDocuments-2_feature_div
# 11 postsSameBrandCard_feature_div
# 13 importantInformation_feature_div
# https://www.amazon.com/Outlet-Compatible-Smartthings-Control-Function/dp/B0B62LPR5Z/ref=sr_1_5?keywords=smart+wifi+plugs&qid=1700496771&sr=8-5
# 3 detailBullets_feature_div
# 4 buffetServiceCard_feature_div
# 5 productDescription_feature_div
# 6 importantInformation_feature_div
# 7 aplusBrandStory_feature_div
# 8 aplus_feature_div
# https://www.amazon.com/TP-LINK-HS103P2-Required-Google-Assistant/dp/B07B8W2KHZ/ref=sr_1_6?keywords=smart+wifi+plugs&qid=1700496771&sr=8-6
# 3 detailBullets_feature_div
# 4 buffetServiceCard_feature_div
# 5 productDescription_feature_div
# 6 importantInformation_feature_div
# 7 aplusBrandStory_feature_div
# 8 aplus_feature_div
# 10 postPurchaseWhatsInTheBox_MP_feature_div
# 11 productDocuments_feature_div
# https://www.amazon.com/sspa/click?ie=UTF8&spc=MToxMDk5NzkzMDI5MTMwNjg4OjE3MDA0OTY3NzE6c3Bfc2VhcmNoX3RoZW1hdGljOjIwMDAxNjA0MTQ0MjY0MTo6MDo6&url=%2FBN-LINK-Monitoring-Function-Compatible-Assistant%2Fdp%2FB07CVPKD8Z%2Fref%3Dsxin_16_pa_sp_search_thematic_sspa%3Fcontent-id%3Damzn1.sym.f1ae5671-a572-4614-89aa-2c9d534241e0%253Aamzn1.sym.f1ae5671-a572-4614-89aa-2c9d534241e0%26cv_ct_cx%3Dsmart%2Bwifi%2Bplugs%26keywords%3Dsmart%2Bwifi%2Bplugs%26pd_rd_i%3DB07CVPKD8Z%26pd_rd_r%3D207500bd-b88e-43de-9bea-a5b10abfc777%26pd_rd_w%3D0M34F%26pd_rd_wg%3Dxl9af%26pf_rd_p%3Df1ae5671-a572-4614-89aa-2c9d534241e0%26pf_rd_r%3D85W6ZM9V4EJ493K4FNDQ%26qid%3D1700496771%26sbo%3D9ZOMT9Jm0JH%252Ft%252BWi68iDSA%253D%253D%26sr%3D1-1-ac07dfd7-5f37-4797-bcf7-0f4905c82761-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9zZWFyY2hfdGhlbWF0aWM%26psc%3D1
# 3 detailBullets_feature_div
# 4 buffetServiceCard_feature_div
# 5 productDescription_feature_div
# 6 importantInformation_feature_div
# 7 aplusBrandStory_feature_div
# 8 aplus_feature_div
# 10 productDocuments_feature_div
# https://www.amazon.com/sspa/click?ie=UTF8&spc=MToxMDk5NzkzMDI5MTMwNjg4OjE3MDA0OTY3NzE6c3Bfc2VhcmNoX3RoZW1hdGljOjIwMDA3NDQ2NjgwMjU5ODo6MTo6&url=%2FTREATLIFE-Compatible-Homekit-Reliable-Required%2Fdp%2FB0B5KC8RF3%2Fref%3Dsxin_16_pa_sp_search_thematic_sspa%3Fcontent-id%3Damzn1.sym.f1ae5671-a572-4614-89aa-2c9d534241e0%253Aamzn1.sym.f1ae5671-a572-4614-89aa-2c9d534241e0%26cv_ct_cx%3Dsmart%2Bwifi%2Bplugs%26keywords%3Dsmart%2Bwifi%2Bplugs%26pd_rd_i%3DB0B5KC8RF3%26pd_rd_r%3D207500bd-b88e-43de-9bea-a5b10abfc777%26pd_rd_w%3D0M34F%26pd_rd_wg%3Dxl9af%26pf_rd_p%3Df1ae5671-a572-4614-89aa-2c9d534241e0%26pf_rd_r%3D85W6ZM9V4EJ493K4FNDQ%26qid%3D1700496771%26sbo%3D9ZOMT9Jm0JH%252Ft%252BWi68iDSA%253D%253D%26sr%3D1-2-ac07dfd7-5f37-4797-bcf7-0f4905c82761-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9zZWFyY2hfdGhlbWF0aWM%26psc%3D1
# 0 bundleV2_feature_div
# 4 detailBullets_feature_div
# 5 buffetServiceCard_feature_div
# 6 productDescription_feature_div
# 7 importantInformation_feature_div
# 8 aplusBrandStory_feature_div
# 9 aplus_feature_div
# 11 postPurchaseWhatsInTheBox_MP_feature_div
# 12 productDocuments_feature_div
# https://www.amazon.com/sspa/click?ie=UTF8&spc=MToxMDk5NzkzMDI5MTMwNjg4OjE3MDA0OTY3NzE6c3Bfc2VhcmNoX3RoZW1hdGljOjMwMDA0NzI2NTEwNTAwMjo6Mjo6&url=%2FMeross-Smart-Plug-Support-Matter%2Fdp%2FB0BRQ5ZGKZ%2Fref%3Dsxin_16_pa_sp_search_thematic_sspa%3Fcontent-id%3Damzn1.sym.f1ae5671-a572-4614-89aa-2c9d534241e0%253Aamzn1.sym.f1ae5671-a572-4614-89aa-2c9d534241e0%26cv_ct_cx%3Dsmart%2Bwifi%2Bplugs%26keywords%3Dsmart%2Bwifi%2Bplugs%26pd_rd_i%3DB0BRQ5ZGKZ%26pd_rd_r%3D207500bd-b88e-43de-9bea-a5b10abfc777%26pd_rd_w%3D0M34F%26pd_rd_wg%3Dxl9af%26pf_rd_p%3Df1ae5671-a572-4614-89aa-2c9d534241e0%26pf_rd_r%3D85W6ZM9V4EJ493K4FNDQ%26qid%3D1700496771%26sbo%3D9ZOMT9Jm0JH%252Ft%252BWi68iDSA%253D%253D%26sr%3D1-3-ac07dfd7-5f37-4797-bcf7-0f4905c82761-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9zZWFyY2hfdGhlbWF0aWM%26psc%3D1
# 0 bundleV2_feature_div
# 4 detailBullets_feature_div
# 5 buffetServiceCard_feature_div
# 6 productDescription_feature_div
# 7 importantInformation_feature_div
# 8 aplusBrandStory_feature_div
# 9 aplus_feature_div
# 11 postPurchaseWhatsInTheBox_MP_feature_div
# 12 productDocuments_feature_div
# https://www.amazon.com/sspa/click?ie=UTF8&spc=MToxMDk5NzkzMDI5MTMwNjg4OjE3MDA0OTY3NzE6c3Bfc2VhcmNoX3RoZW1hdGljOjIwMDAxODg5NzY4MjU2MTo6Mzo6&url=%2FHBN-Individual-Grounded-Compatible-Assistant%2Fdp%2FB07XZJ412P%2Fref%3Dsxin_16_pa_sp_search_thematic_sspa%3Fcontent-id%3Damzn1.sym.f1ae5671-a572-4614-89aa-2c9d534241e0%253Aamzn1.sym.f1ae5671-a572-4614-89aa-2c9d534241e0%26cv_ct_cx%3Dsmart%2Bwifi%2Bplugs%26keywords%3Dsmart%2Bwifi%2Bplugs%26pd_rd_i%3DB07XZJ412P%26pd_rd_r%3D207500bd-b88e-43de-9bea-a5b10abfc777%26pd_rd_w%3D0M34F%26pd_rd_wg%3Dxl9af%26pf_rd_p%3Df1ae5671-a572-4614-89aa-2c9d534241e0%26pf_rd_r%3D85W6ZM9V4EJ493K4FNDQ%26qid%3D1700496771%26sbo%3D9ZOMT9Jm0JH%252Ft%252BWi68iDSA%253D%253D%26sr%3D1-4-ac07dfd7-5f37-4797-bcf7-0f4905c82761-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9zZWFyY2hfdGhlbWF0aWM%26psc%3D1
# 3 detailBullets_feature_div
# 4 buffetServiceCard_feature_div
# 5 productDescription_feature_div
# 6 importantInformation_feature_div
# 7 aplusBrandStory_feature_div
# 8 aplus_feature_div
# 10 postPurchaseWhatsInTheBox_MP_feature_div
# 11 productDocuments_feature_div

# %%
product_details
# Out:
# {'Amazon Smart Plug | Works with Alexa | control lights with voice | easy to set up and use': {'data': {'product_title': 'Amazon Smart Plug | Works with Alexa | control lights with voice | easy to set up and use',
#    'product_brand': 'Brand: Amazon',
#    'product_brand_url': 'https://www.amazon.com/Amazon/b/ref=bl_dp_s_web_20784502011?ie=UTF8&node=20784502011&field-lbr_brands_browse-bin=Amazon',
#    'product_overview': {},
#    'product_about': "Amazon Smart Plug works with Alexa to add voice control to any outlet. Certified for Humans - Struggle-free, tinker-free, stress-free. No patience neededit's actually simple. Schedule lights, fans, and appliances to turn on and off automatically, or control them remotely when youre away. Simple to set up and useplug in, open the Alexa app, and get started in minutes. Compact design keeps your second outlet free. No smart home hub requiredset up routines and schedules through the Alexa app.",
#    'sac-btf-start_feature_div': 'Smart home devices for you\nExplore best-selling devices that work with Alexa\nSmart Lighting\nSecurity Cameras\nPlugs and outlets\nVacuums\nSmart locks\nWifi and Networking\nHome Entertainment\n"Alexa, turn on the lights."\nControl the lights with your voice.\nGovee Permanent Outdoor Lights, S…\n1,072\n$199.99\nGovee Permanent Outdoor Lights, S…\n1,072\n$299.99\nGovee Smart Light Bulbs, WiFi Blueto…\n7,089\n$39.99\nAmazon Basics - Smart A19 LED Lig…\n12,016\n$10.39\nGovee RGBIC Floor Lamp, LED Corner…\n3,486\n$59.99\nGovee Smart Outdoor String Lig…\n3,128\n$57.99',
#    'device-dp-recommendations_feature_div': 'Customers also bought these items from Amazon Devices\nEcho Pop | Full sound compact smart speaker with Alexa - Midnight Teal + 4 months of Amazon Music Unlimited FREE\n18,210\n$17.99\nEcho Show 8 (2nd Gen, 2021 release) | HD smart display with Alexa and 13 MP camera | Glacier White\n80,164\n58% off\nBlack Friday Deal\n$54.99\nList:\u2009$129.99\nGet it as soon as Saturday, Nov 25\nFREE Shipping by Amazon\n Climate Pledge Friendly\nAmazon Adjustable Stand for Echo Show 5 (3rd Gen), Built-In USB-C Charging Port | Charcoal\n2,273\n26% off\nBlack Friday Deal\n$19.99\nList:\u2009$26.99\nGet it as soon as Saturday, Nov 25\nFREE Shipping on orders over $35 shipped by Amazon\nEcho Dot (5th Gen, 2022 release) with clock - Cloud Blue and 4 months of Amazon Music Unlimited FREE w/ auto-renewal\n53,017\n$34.99\nEcho Show 8 (3rd Gen) Adjustable Stand with USB-C Charging Port | Charcoal\n40\n$34.99\nGet it as soon as Saturday, Nov 25\nFREE Shipping on orders over $35 shipped by Amazon\n Climate Pledge Friendly',
#    'btfContent1_feature_div': "Make your home smart\nAmazon Smart Plug lets you voice control your lights, fans, coffee makers, and more. All you need is an Alexa-enabled device like Echo, Fire TV, Fire tablet, Sonos One, or even just the Alexa app on your phone. With multiple Amazon Smart Plugs, you can control multiple outlets.\nSet up helpful routines\nUse the Alexa app to create routines for your Amazon Smart Plug that make life easier. For example, set a morning routine that turns on lights and your coffee maker with a single request.\nMake it look like you're home",
#    'btfContent5_feature_div': 'With Away Lighting, Alexa can automatically turn connected lights on and off to make it look like you’re home when you’re away.\nTo use Away Lighting, all you need is a light connected to an Amazon Smart Plug and the Alexa app. Connect your plug to a lamp, then let Alexa know when you come and go. Learn about Away Lighting and more with Alexa Guard Plus.',
#    'btfContent7_feature_div': 'Use your Amazon Smart Plug to turn on and off compatible devices that have a mechanical on/off switch.\nCertified for Humans\nIntroducing Certified for Humans, smart devices for non-experts. Struggle-free, tinker-free, and stress-free. No patience needed. Setup with Alexa is simple and after that, it only gets better. No more waiting on unresponsive devices or software updates to get started. It’s smart home made easy. Learn more about Certified for Humans.\nEvery day is an earth day\nYou don’t have to be an environmental scientist to make sustainable choices. We considered sustainability in the design of this smart plug. Here’s how:\nDevice Packaging\n99% of this device’s packaging is made of wood fiber-based materials from responsibly managed forests or recycled sources.\nAlexa\nTrack and manage the energy usage of your Alexa-connected devices with the energy dashboard in the Alexa app.\nPart With Purpose\nThere may come a time when you want to recycle your device. Explore options with Amazon Second Chance.\nSimple to set up and use\nStep 1\nPlug in Amazon Smart Plug. If your Alexa app says “New plug found,” go straight to Step 3.\nStep 2\nTap the Devices icon in the lower right of the Alexa App, then click the + icon to get started.\nStep 3\nTo use your device with Alexa, just say “Alexa, turn on First Plug.”\nWith Wi-Fi simple setup, you can make your home smart in a snap. All you need is the Alexa app to control your outlet from anywhere.',
#    'btfContent8_feature_div': {'Size': '3.2” x 1.5” x 2.2” (80 mm x 38 mm x 57 mm)',
#     'Weight': '3.1 oz. (87 grams) Actual size and weight may vary by manufacturing process',
#     'Electrical Ratings': 'Input: 120VAC, 60Hz 15A\nMax Output: 15A Max',
#     'Network Connectivity': '2.4 GHz only, 802.11 b/g/n. Does not support 5GHz networks or connecting to ad-hoc (or peer-to-peer) Wi-Fi networks.',
#     'Use': 'For indoor use only.',
#     'Integrations': 'Amazon Smart Plug is optimized for simple setup and exclusive use with Alexa. Amazon Smart Plug does not support other voice assistants or smart hubs.',
#     'Alexa App': 'The Alexa app is compatible with Fire OS, Android, and iOS devices. A list of supported operating systems can be found here.'},
#    'climatePledgeFriendlyBTF_feature_div': 'Climate Pledge Friendly\nProducts with trusted sustainability certification(s). Learn more\nProduct Certification (1)\nReducing CO2 products reduce their carbon footprint year after year. Certified by the Carbon Trust.'},
#   'images': ['https://m.media-amazon.com/images/I/51yEWwZlHrL._AC_SY300_SX300_.jpg',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/I/61WMzpZQMvL._AC_UL160_SR160,160_.jpg',
#    'https://images-na.ssl-images-amazon.com/images/I/51swTkrXwFL._AC_UL160_SR160,160_.jpg',
#    'https://m.media-amazon.com/images/I/216-OX9rBaL._SS72_.png',
#    'https://m.media-amazon.com/images/I/31FqTrWUyTL._SS180_.png',
#    'https://images-na.ssl-images-amazon.com/images/I/51iVkKCRK4L._AC_UL160_SR160,160_.jpg',
#    'https://images-na.ssl-images-amazon.com/images/I/81wmtcLUSAL._AC_UL160_SR160,160_.jpg',
#    'https://images-na.ssl-images-amazon.com/images/I/71I8-j1+I0L._AC_UL160_SR160,160_.jpg',
#    'https://m.media-amazon.com/images/I/216-OX9rBaL._SS72_.png',
#    'https://m.media-amazon.com/images/I/41j5MRVQO6L._SS180_.png',
#    'https://m.media-amazon.com/images/G/01/kindle/journeys/73lytr274IF6rT4xcSb76LuLKu6X56SmHNFJgFbbC9w3D/OTdhYmUxZjQt',
#    'https://m.media-amazon.com/images/G/01/kindle/journeys/73lytr274IF6rT4xcSb76LuLKu6X56SmHNFJgFbbC9w3D/MDg3ZGZlNzYt._CB654750988_.jpg',
#    'https://m.media-amazon.com/images/G/01/kindle/journeys/73lytr274IF6rT4xcSb76LuLKu6X56SmHNFJgFbbC9w3D/ZTNlNDA4NjYt',
#    'https://m.media-amazon.com/images/G/01/kindle/2020/SH/Schooner_Desktop_Pack_4.PNG',
#    'https://m.media-amazon.com/images/G/01/kindle/dp/2018/73493429/ASP_p3_icons_v2._CB483451276_.gif',
#    'https://m.media-amazon.com/images/G/01/kindle/dp/2018/73493429/ASP_p3_800x555._CB483405930_.jpg',
#    'https://m.media-amazon.com/images/G/01/kindle/journeys/73lytr274IF6rT4xcSb76LuLKu6X56SmHNFJgFbbC9w3D/ZjEwYWQyNmQt._CB654751172_.jpg',
#    'https://m.media-amazon.com/images/G/01/kindle/mako/features/sustainability/packing._CB406459720_.png',
#    'https://m.media-amazon.com/images/G/01/kindle/mako/features/sustainability/alexa._CB406459720_.png',
#    'https://m.media-amazon.com/images/G/01/kindle/mako/features/sustainability/tradeinrecycle._CB657051856_.png',
#    'https://m.media-amazon.com/images/G/01/kindle/journeys/73lytr274IF6rT4xcSb76LuLKu6X56SmHNFJgFbbC9w3D/NGQyMWZhYTYt._CB654639657_.jpg',
#    'https://m.media-amazon.com/images/G/01/kindle/journeys/73lytr274IF6rT4xcSb76LuLKu6X56SmHNFJgFbbC9w3D/ODA1NDA1MGIt._CB654639657_.jpg',
#    'https://m.media-amazon.com/images/G/01/kindle/journeys/73lytr274IF6rT4xcSb76LuLKu6X56SmHNFJgFbbC9w3D/NzdjM2M4NDIt._CB654639657_.jpg',
#    'https://m.media-amazon.com/images/G/01/kindle/journeys/73lytr274IF6rT4xcSb76LuLKu6X56SmHNFJgFbbC9w3D/YTNjOTlmZjYt._CB654750231_.jpg',
#    'https://m.media-amazon.com/images/I/111pigi1ylL.png',
#    'https://m.media-amazon.com/images/I/31FqTrWUyTL._SS128_.png']},
#  'BN-LINK WiFi Heavy Duty Smart Plug Outlet, No Hub Required with Timer Function, White, Compatible with Alexa and Google Assistant, 2.4 Ghz Network Only (2 Pack)': {'data': {'product_title': 'BN-LINK WiFi Heavy Duty Smart Plug Outlet, No Hub Required with Timer Function, White, Compatible with Alexa and Google Assistant, 2.4 Ghz Network Only (2 Pack)',
#    'product_brand': 'Visit the BN-LINK Store',
#    'product_brand_url': 'https://www.amazon.com/stores/BN-LINK/page/D971F404-458D-48FE-9864-747565711EBB?ref_=ast_bln',
#    'product_overview': {'Operation Mode': 'Automatically,Off',
#     'Current Rating': '15 Amps',
#     'Operating Voltage': '125 Volts',
#     'Connector Type': 'Plug In',
#     'Brand': 'BN-LINK',
#     'Item Dimensions LxWxH': '3 x 2 x 2 inches',
#     'Actuator Type': 'Push Button',
#     'International Protection Rating': 'IP00',
#     '': 'Specification Met\nETL',
#     'Switch Type\nPush Button': '',
#     'Mounting Type\nPlug-In Mount': ''},
#    'product_about': '[VOICE CONTROL]: Simply voice command to control multiple home devices with our smart outlet via Alexa or Google Home. Enjoy the hands-free convenience of controlling any home electronic appliances. Made for everyone, perfect for elderly, disabled, or for hard-to-reach plugs [CONTROL FROM ANYWHERE]: Turn electronics on or off from anywhere in the world with your smartphone using the BN-LINK app or by simply giving voice commands to Amazon Alexa or Google Home Assistant. No Hub Required, works with 2.4GHz network [SMART SCHEDULING]: Set the wifi smart plug to automatically power most electronics on and off as needed. With timer function setting lamps, fan, humidifier, any lights to come on at dusk and turn off at anytime [GROUP & SHARE CONTROL]: The convenient and efficient group control function allows you to share these wifi smart plugs to all family members in a minute. Let no more worries. Everyone can control it easily [EASY TO SET UP,SAFE TO USE]: Requires a secured 2.4 GHz Wi-Fi network connection. ETL certified. Rated: 15 A, 125 V, 1875 W',
#    'detailBullets_feature_div': 'Product details\nIs Discontinued By Manufacturer : No\nProduct Dimensions : 3 x 2 x 2 inches; 6.38 Ounces\nItem model number : BNC-60/U133T\nDate First Available : May 4, 2018\nManufacturer : BN-LINK\nASIN : B07CVPKD8Z\nBest Sellers Rank: #469 in Tools & Home Improvement (See Top 100 in Tools & Home Improvement)\n#19 in Electrical Outlet Switches\nCustomer Reviews:\n4.2\n20,039 ratings',
#    'importantInformation_feature_div': 'Important information\nTo report an issue with this product, click here.',
#    'aplusBrandStory_feature_div': "From the brand\nAbout BN-LINK:\nA direct distributor of premium quality home improvement products. We strive to provide better products and after-sales service to help every customer's life easier and more convenient.\nOur Products: remote control outlets, indoor & outdoor timers, smart plugs, heating & cooling thermostat controllers.\nINDOOR TIMER OUTLET\nVisit the Store\nSMART PLUG\nVisit the Store",
#    'aplus_feature_div': {'': 'BN-LINK Smart Plug Outlet',
#     'Indoor/Outdoor': 'Indoor',
#     'Plug In/In-Wall': 'Plug In',
#     'Compatible with Alexa': '',
#     'Work with Google Assistant': '',
#     'Package includes': '2 pack'},
#    'productDocuments_feature_div': 'Product guides and documents\nApplication Guide (PDF)\nUser Manual (PDF)\nUser Guide (PDF)'},
#   'images': ['https://m.media-amazon.com/images/I/51FpsvJlDAS._SX522_.jpg',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/561923ab-e389-47fb-9cd7-1d31a6050741.__CR0,0,1464,600_PT0_SX1464_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/8e6cacda-c19e-4911-90f8-b830cb930a1e.__CR0,0,1464,600_PT0_SX1464_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/55d3b92a-75ac-4c87-816d-c8b0cf36b2e4.__CR0,0,1464,600_PT0_SX1464_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/d18590f4-7c84-48a5-8e79-78b4b24f2853.__CR0,0,1464,600_PT0_SX1464_V1___.jpg',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/5ca6cbf2-874b-49fb-b810-59bd21f46b02.__CR0,0,200,225_PT0_SX200_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/68a71e99-8ab9-4009-81a2-c0b3e7a86193.__CR0,0,200,225_PT0_SX200_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/e62874a7-5952-4e52-8c9a-f168ca7a9aa6.__CR0,0,200,225_PT0_SX200_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/e2954d10-ce7f-44ea-a949-1a73aa95be00.__CR0,0,200,225_PT0_SX200_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/22a2a19f-8c0f-4f5f-92e7-552d9fa495b2.__CR0,0,200,225_PT0_SX200_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/21a4d3ea-3ff2-488e-b0c0-c52ca02523cb.__CR0,0,200,225_PT0_SX200_V1___.jpg',
#    'https://m.media-amazon.com/images/G/01/kindle/dp/2015/mobile/AUI-checkmark-2._CB485934104_.png',
#    'https://m.media-amazon.com/images/G/01/kindle/dp/2015/mobile/AUI-checkmark-2._CB485934104_.png',
#    'https://m.media-amazon.com/images/G/01/kindle/dp/2015/mobile/AUI-checkmark-2._CB485934104_.png',
#    'https://m.media-amazon.com/images/G/01/kindle/dp/2015/mobile/AUI-checkmark-2._CB485934104_.png',
#    'https://m.media-amazon.com/images/G/01/kindle/dp/2015/mobile/AUI-checkmark-2._CB485934104_.png',
#    'https://m.media-amazon.com/images/G/01/kindle/dp/2015/mobile/AUI-checkmark-2._CB485934104_.png',
#    'https://m.media-amazon.com/images/G/01/kindle/dp/2015/mobile/AUI-checkmark-2._CB485934104_.png',
#    'https://m.media-amazon.com/images/G/01/kindle/dp/2015/mobile/AUI-checkmark-2._CB485934104_.png',
#    'https://m.media-amazon.com/images/G/01/kindle/dp/2015/mobile/AUI-checkmark-2._CB485934104_.png',
#    'https://m.media-amazon.com/images/G/01/kindle/dp/2015/mobile/AUI-checkmark-2._CB485934104_.png',
#    'https://m.media-amazon.com/images/G/01/kindle/dp/2015/mobile/AUI-checkmark-2._CB485934104_.png',
#    'https://m.media-amazon.com/images/G/01/kindle/dp/2015/mobile/AUI-checkmark-2._CB485934104_.png']},
#  'SONOFF S40 WiFi Smart Plug with Energy Monitoring, 15A Smart Outlet Socket ETL Certified, Work with Alexa & Google Home Assistant, IFTTT Supporting, 2.4 Ghz WiFi Only (4-Pack)': {'data': {'product_title': 'SONOFF S40 WiFi Smart Plug with Energy Monitoring, 15A Smart Outlet Socket ETL Certified, Work with Alexa & Google Home Assistant, IFTTT Supporting, 2.4 Ghz WiFi Only (4-Pack)',
#    'product_brand': 'Visit the SONOFF Store',
#    'product_brand_url': 'https://www.amazon.com/stores/Sonoff/page/8D527F70-DC57-4072-B079-C2B4D6E1055A?ref_=ast_bln',
#    'product_overview': {'Brand': 'SONOFF',
#     'Material': 'Plastic',
#     'Connector Type': 'Plug in',
#     'Specification Met': 'ETL'},
#    'product_about': '[Monitor Energy Consumption]:Keep track of real-time power, current and voltage of your appliances on App.and Measure your appliances power consumption for 100-day daily/monthly energy usage data and total electricity cost. [Works with Alexa & Google Home,IFTTT Supporting]: Link "eWeLink Smart Home" skill. You can directly ask Amazon Echo/Echo Dot/Amazon Tap to turn on/off your SONOFF devices.Link "eWeLink Smart Home" on Google Home app, start to voice control your SONOFF devices on Google Home. [Smart Remote Control Plug]: You can remotely/timely control ON/OFF any connected home appliance via APP eWeLink on your smart phone or tablet. No distance/time limitation. [Set time schedules for the lights and home appliances]: You can set countdown/single/repeat timers to auto-turn on/off the WiFi controlled outlet on App. One tap ON/OFF Energy Saving. [Share control of devices to others]: You can simply share control of your home appliances to others so that they can also turn on/off the devices remotely.',
#    'aplusBrandStory_feature_div': 'From the brand\nSONOFF\nFoster innovation to make life simpler and smarter.\nSONOFF specializes in the development and production of smart home hardware and products.\nIt is located in Shenzhen, which is the Chinese electronics market, and due to our strong production capacity, SONOFF is able to provide high-quality products at an affordable cost.\nSONOFF WiFi Smart Home\nVisit the Store\nSONOFF Smart Home\nVisit the Store',
#    'aplus_feature_div': 'Product Description\nSONOFF S40 15A WiFi Smart Plug with Energy Monitoring\nPlay Video\n4Pack+eWelink eWelink Advanced Support IFTTT\nEnergy Monitoring SONOFF Energy Dashboard Alexa Energy Dashboard\nNew eWelink pairing combines Quick pairing, BLT pairing, etc., which is simpler and more stable.\nConnect with eWelink App Connect with Alexa Connect with Google Home\nControl your device from anywhere anytime\nForget to turn off the coffee maker? Just take out your phone and turn it off anywhere.\nRemote Control Voice Control LAN Control NFC-Tag Cnotrol Share Control\nSafety Design\nETL Certified: The SONOFF S40 has been rigorously tested for safety with ETL Certified ( Control Number: 5017124; ATM Issued: 24-Mar-2022)\nOver-load Protection: When the limit power is exceeded or a short circuit occurs, the fuse automatically fuses to protect the device\nHighest Flame-retardant: The Most flame-retardant grade V-0 device enclosure\nUltrasonic Machining: The fine ultrasonic Machining makes the shell non-removable and more secure',
#    'productDetailsNonPets_feature_div': {'Manufacturer': 'SONOFF',
#     'Part Number': 'S40TPB',
#     'Item Weight': '11.7 ounces',
#     'Product Dimensions': '6.1 x 1.77 x 3.7 inches',
#     'Item model number': 'S40TPB',
#     'Size': 'S40 4-Pack',
#     'Material': 'Plastic',
#     'Mounting Type': 'Plug In Mount',
#     'Certification': 'ETL',
#     'Batteries Included?': 'No',
#     'Batteries Required?': 'No'},
#    'productDocuments-2_feature_div': 'Product guides and documents\nInstallation Manual (PDF)\nUser Manual (PDF)\nProduct Documentation (PDF)\nUser Guide (PDF)',
#    'importantInformation_feature_div': 'Important information\nTo report an issue with this product, click here.'},
#   'images': ['https://m.media-amazon.com/images/I/61nCuSMaN4L._AC_SX679_.jpg',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/868ab9be-5577-4ffb-943b-39aa3d109a30.__CR0,0,1464,600_PT0_SX1464_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/7a9a1831-15ff-46ca-a8c9-fa9e919784ba.__CR0,0,1464,600_PT0_SX1464_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/c90f4b6e-6fee-4a82-8a46-8b297b6cf042.__CR0,0,1464,600_PT0_SX1464_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/6d128a37-d50d-45a3-8e48-5001836fc849.__CR0,0,1464,600_PT0_SX1464_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/1d44a703-e717-4eff-ab43-fe26012490f3.__CR0,0,1464,600_PT0_SX1464_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/8d95ba5e-d366-415d-94cf-d4bf21bcf3fe.__CR0,0,1464,600_PT0_SX1464_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/572c8874-b9ad-4b34-b281-485bf22ab6c4.__CR0,0,1464,600_PT0_SX1464_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/1b744be6-c2d8-4a6f-8598-fefd6a87f106.__CR0,0,1464,600_PT0_SX1464_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/719eaf95-7088-467a-8698-10863dba09ae.__CR0,0,1464,600_PT0_SX1464_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/e70276fa-5300-41eb-95e5-52874c1b5c64.__CR0,0,1464,600_PT0_SX1464_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/4d0cc3df-a6eb-4001-b3be-c4b8a07734f9.__CR0,0,1464,600_PT0_SX1464_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/3b4b7d53-1561-4b6f-9a9a-8a68ef954b3e.__CR0,0,1464,600_PT0_SX1464_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/4a8f8499-fbac-49e1-bf34-ca2646de8860.__CR0,0,1464,600_PT0_SX1464_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/cb81fccf-48aa-462f-977b-7a9e79d957e3.__CR0,0,1464,600_PT0_SX1464_V1___.jpg',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://m.media-amazon.com/images/I/411uicVV-sL._SS75_.jpg']},
#  'Kasa Smart Plug HS103P4, Smart Home Wi-Fi Outlet Works with Alexa, Echo, Google Home & IFTTT, No Hub Required, Remote Control, 15 Amp, UL Certified, 4-Pack, White': {'data': {'product_title': 'Kasa Smart Plug HS103P4, Smart Home Wi-Fi Outlet Works with Alexa, Echo, Google Home & IFTTT, No Hub Required, Remote Control, 15 Amp, UL Certified, 4-Pack, White',
#    'product_brand': 'Visit the Kasa Smart Store',
#    'product_brand_url': 'https://www.amazon.com/stores/KasaSmartbyTP-Link/page/9A672382-E380-4360-A698-DFBEAE7E7049?ref_=ast_bln',
#    'product_overview': {'Brand': 'Kasa Smart',
#     'Color': 'Indoor Plug 4-Pack',
#     'Connector Type': 'Plug in',
#     'No. of wires': '3',
#     'Plug Format': 'Type B'},
#    'product_about': 'Voice control: Kasa smart plugs that work with Alexa and Google Home Assistant. Enjoy the hands free convenience of controlling any home electronic appliances with your voice via Amazon Alexa or Google Assistant. Compatible with Android 5.0 or higher and iOS 10.0 or higher Smart Outlet Control from anywhere: Turn electronics on and off your smart home devices from anywhere with your smartphone using the Kasa app, whether you are at home, in the office or on vacation Scheduling: Use timer or countdown schedules to set your wifi smart plug to automatically turn on and off any home electronic appliances such as lamps, fan, humidifier, Christmas lights etc. The Kasa app is free and compatible with iOS 10.0 or later. Easy set up and use: 2.4GHz Wi-Fi connection required. Plug in, open the Kasa app, follow the simple instructions and enjoy Trusted and reliable: Designed and developed in Silicon Valley, Kasa is trusted by over 5 Million users and being the readers choice for PCMag 2020. UL certified for safety use.',
#    'aplusBrandStory_feature_div': 'From the brand\nLeading Smart Home Brand\nLaunched in 2015, Kasa Smart quickly became a leading smart home brand giving convenience, fun, and security to over 7 million delighted users and has garnered praises from PCMag, Wirecutter, and more. Users can control their lights, appliances, and view security camera footage from anywhere, anytime. Kasa offers terrific synergy between devices for enhanced automation.\nKasa Best Sellers\nVisit the Store\nSmart Wi-Fi Plugs\nVisit the Store',
#    'aplus_feature_div': "From the manufacturer\nVoice Control\nFree up your hands by using simple voice commands with Alexa and Google Assistant.\nVoice Control Control from Anywhere Grouping\nSmart Actions\nCreate interactions with your plug and other Kasa products. Connect a lamp to your plug so that when your camera detects motion, your light turns on.\nApp Features\nScheduling\nSchedule your connected devices to turn on and off automatically at specified times.\nCount Down Timer\nSet a timer for your connected appliance to automatically turn off when the time runs out.\nAway Mode\nAway Mode will automatically turn on and off connected appliances, like lamps, to make it appear as if you're home.\nRun Time & Usage\nView run times to track usage and cut down on energy consumption.\nSimple Setup",
#    'productDescription-3_feature_div': 'Product Description\nThe HS103 Kasa smart plug is the easiest way you can start controlling lamps, fans, humidifiers and other home electronic appliances. With it adding voice control to any outlet, you could also enjoy the hands-free convenience. The Kasa app contains not only all the feature you expect from TP-Link Kasa family, but also guidance for you through each step of the installation to connect your smart plug with your home Wi-Fi, Alexa or Google assistant.',
#    'productDetailsNonPets_feature_div': {'Manufacturer': 'TP-Link',
#     'Part Number': 'HS103P4',
#     'Item Weight': '4 ounces',
#     'Product Dimensions': '1.57 x 1.5 x 2.62 inches',
#     'Country of Origin': 'Vietnam',
#     'Item model number': 'HS103P4',
#     'Size': '4 Count (Pack of 1)',
#     'Color': 'Indoor Plug 4-Pack',
#     'Style': 'Mini 4-Pack',
#     'Pattern': 'WiFi Outlet',
#     'Power Source': 'Corded Electric',
#     'Item Package Quantity': '1',
#     'Number Of Pieces': '4',
#     'Measurement Accuracy': '0.1',
#     'Mounting Type': 'Plug-In Mount',
#     'Plug Format': 'Type B',
#     'Included Components': 'HS103 Smart Wi-Fi Plug Lite (4)',
#     'Batteries Included?': 'No',
#     'Batteries Required?': 'No',
#     'Warranty Description': '2 year manufacturer'},
#    'productDocuments-2_feature_div': 'Product guides and documents\nUser Guide (PDF)\nSpecification Sheet (PDF)',
#    'importantInformation_feature_div': 'Important information\nTo report an issue with this product, click here.'},
#   'images': ['https://m.media-amazon.com/images/I/51zoLDBO0wL._AC_SX679_PIbundle-4,TopRight,0,0_SH20_.jpg',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://m.media-amazon.com/images/S/aplus-media/vc/1eb0cd16-37c1-4f9a-bb5e-ded526dbe7b2.__CR0,0,1464,600_PT0_SX1464_V1___.png',
#    'https://m.media-amazon.com/images/S/aplus-media/vc/688e4663-2901-4dcb-b024-63703ec7723e.__CR0,0,1464,600_PT0_SX1464_V1___.png',
#    'https://m.media-amazon.com/images/S/aplus-media/vc/e599bb1d-b81c-48d4-b136-531e3a31c2f6.__CR0,0,1464,600_PT0_SX1464_V1___.png',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://m.media-amazon.com/images/I/41JnNfpIRXL._SS75_.jpg']},
#  'EIGHTREE Smart Plug, Smart Home WiFi Outlet Compatible with Alexa & Google Home, Alexa Smart Socket with Remote Control & Timer Function, 2.4GHz WiFi Only': {'data': {'product_title': 'EIGHTREE Smart Plug, Smart Home WiFi Outlet Compatible with Alexa & Google Home, Alexa Smart Socket with Remote Control & Timer Function, 2.4GHz WiFi Only',
#    'product_brand': 'Visit the EIGHTREE Store',
#    'product_brand_url': 'https://www.amazon.com/stores/EIGHTREE-SmartLifeEasyHome/page/EFDC81BC-50C7-4D9D-B4B9-AD9068339931?ref_=ast_bln',
#    'product_overview': {'Operation Mode': 'ON-OFF',
#     'Current Rating': '10 Amps',
#     'Operating Voltage': '240 Volts',
#     'Contact Type': 'Remote Control',
#     'Connector Type': 'Plug In',
#     'Brand': 'EIGHTREE',
#     'Item Dimensions LxWxH': '4.06 x 4.06 x 2.28 inches',
#     'Circuit Type': '3-way',
#     '': 'Specification Met\nEtl, Fcc, Ic',
#     'Switch Type\nTouch Switch, Temperature Switch': '',
#     'Mounting Type\nPlug-In Mount': ''},
#    'product_about': 'Simplified Setup: Our upgraded smart plug makes connecting a breeze. Just open the Smart Life App, and your phone\'s Bluetooth will automatically find the plug. No more worrying about complicated setups. Voice Control: Smart plugs that work with Alexa and Google Home Assistant. Free your hands with a simple voice command: "Alexa, turn on the fan". Remote Control: Use your smartphone to turn home devices on and off from anywhere, anytime. Grab an Alexa smart plug for those electronics you sometimes forget, saving energy and ensuring safe power usage. Schedule & Timer Function:: You can easily set timers, countdowns, cycles, or random schedules. For example, schedule the coffee maker to turn on automatically at 8 a.m. and the lights to turn off at 10 p.m. Reliable & Compact: The mini\'s round design ensures it won\'t take up extra space. Rest assured with ETL and FCC certifications, and enjoy peace of mind with EIGHTREE\'s 2-year warranty. Warm Tips: To use Alexa and Google Home for voice control, please take a minute to connect the Smart Home plug with the Smart Life App first. Warm Tips: Our smart outlet is compatible with SmartThings. Please follow the connection instruction video to complete the setup. Feel free to reach out to us if you need any assistance. We\'re here for you every step of the way!',
#    'detailBullets_feature_div': 'Product details\nProduct Dimensions : 4.06 x 4.06 x 2.28 inches; 8.15 Ounces\nItem model number : ET01B-4\nDate First Available : July 8, 2022\nManufacturer : EIGHTREE\nASIN : B0B62LPR5Z\nBest Sellers Rank: #718 in Tools & Home Improvement (See Top 100 in Tools & Home Improvement)\n#22 in Electrical Outlet Switches\nCustomer Reviews:\n4.4\n1,580 ratings',
#    'importantInformation_feature_div': 'Important information\nTo report an issue with this product, click here.',
#    'aplusBrandStory_feature_div': 'From the brand\nSwipe left to learn more ⊳⊳⊳\nAbout Eightree\nEightree is an up-and-coming brand established in 2021, dedicated to product development and manufacturing in the field of smart home.\nOur mission is to provide more convenient, high quality but affordable smart home solutions for people around the world.\nSmart home never needs to be expensive, just enjoy the convenience that smart home brings to your life. Eightree is always at your service.\nSmart Plugs Alexa Compatible',
#    'aplus_feature_div': 'Product Description\nVoice Control Timer & Schedule Device Sharing\nHow to connect smart plug?\nWhat to do when connection fails？\nHow do I use the plug to work with third-party voice assistants?\nWhat should I do if my smart hom plug is broken?'},
#   'images': ['https://m.media-amazon.com/images/I/519c4e-dU8L._SX522_.jpg',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/57302396-8c77-4715-87ff-b88889084738.__CR0,0,1464,600_PT0_SX1464_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/ba5a7c37-4f9b-4f74-bbd4-d4f8c94b33b1.__CR0,0,1464,600_PT0_SX1464_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/875144bb-8303-4799-a7d2-d8446225b3b6.__CR0,0,1464,600_PT0_SX1464_V1___.jpg',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif']},
#  'Kasa Smart Plug HS103P2, Smart Home Wi-Fi Outlet Works with Alexa, Echo, Google Home & IFTTT, No Hub Required, Remote Control,15 Amp,UL Certified, 2-Pack White': {'data': {'product_title': 'Kasa Smart Plug HS103P2, Smart Home Wi-Fi Outlet Works with Alexa, Echo, Google Home & IFTTT, No Hub Required, Remote Control,15 Amp,UL Certified, 2-Pack White',
#    'product_brand': 'Visit the Kasa Smart Store',
#    'product_brand_url': 'https://www.amazon.com/stores/KasaSmartbyTP-Link/page/9A672382-E380-4360-A698-DFBEAE7E7049?ref_=ast_bln',
#    'product_overview': {'Brand': 'Kasa Smart',
#     'Color': 'White',
#     'Product Dimensions': '1.6"D x 2.6"W x 1.5"H',
#     'Connector Type': 'Plug in',
#     'No. of wires': '3'},
#    'product_about': 'Voice Control: Add voice control to any outlet. Enjoy the hands-free convenience of controlling any home electronic appliances with your voice via Amazon Alexa or Google Assistant. Control From Anywhere: Turn electronics on and off from anywhere with your smartphone using the Kasa app, whether you are at home, in the office or on vacation. Scheduling: Use timer or countdown schedules set your smart plug to automatically turn on and off any home electronic appliances such as lamps, fan, humidifier, Christmas lights etc. The button on the side of each HS103 Smart Plug will toggle the power state of the Smart Plug, and the appliance connected to it. Easy Set Up and Use: 2.4GHz Wi-Fi connection required. Plug in, open the Kasa app, follow the simple instructions and enjoy. Trusted and Reliable: Designed and developed in Silicon Valley, Kasa is trusted by over 4 Million users and being the readers choice for PCMag 2020. UL certified for safety use.',
#    'detailBullets_feature_div': 'Product details\nIs Discontinued By Manufacturer : No\nProduct Dimensions : 1.5 x 1.57 x 2.62 inches; 6.74 Ounces\nItem model number : HS103P2\nDate First Available : March 6, 2018\nManufacturer : TP-LINK\nASIN : B07B8W2KHZ\nCountry of Origin : Vietnam\nBest Sellers Rank: #36 in Tools & Home Improvement (See Top 100 in Tools & Home Improvement)\n#5 in Electrical Outlet Switches\nCustomer Reviews:\n4.6\n67,680 ratings',
#    'productDescription_feature_div': 'Product Description\nThe HS103 Kasa smart plug is the easiest way you can start controlling lamps, fans, humidifiers and other home electronic appliances. With it adding voice control to any outlet, you could also enjoy the hands-free convenience. The Kasa app contains not only all the feature you expect from TP-Link Kasa family, but also guidance for you through each step of the installation to connect your smart plug with your home Wi Fi, Alexa or Google assistant.',
#    'importantInformation_feature_div': 'Important information\nTo report an issue with this product, click here.',
#    'aplusBrandStory_feature_div': 'From the brand\nLeading Smart Home Brand\nLaunched in 2015, Kasa Smart quickly became a leading smart home brand giving convenience, fun, and security to over 7 million delighted users and has garnered praises from PCMag, Wirecutter, and more. Users can control their lights, appliances, and view security camera footage from anywhere, anytime. Kasa offers terrific synergy between devices for enhanced automation.\nKasa Best Sellers\nVisit the Store\nSmart Wi-Fi Plugs\nVisit the Store',
#    'aplus_feature_div': "From the manufacturer\nVoice Control\nFree up your hands by using simple voice commands with Alexa and Google Assistant.\nVoice Control Control from Anywhere Grouping\nSmart Actions\nCreate interactions with your plug and other Kasa products. Connect a lamp to your plug so that when your camera detects motion, your light turns on.\nApp Features\nScheduling\nSchedule your connected devices to turn on and off automatically at specified times.\nCount Down Timer\nSet a timer for your connected appliance to automatically turn off when the time runs out.\nAway Mode\nAway Mode will automatically turn on and off connected appliances, like lamps, to make it appear as if you're home.\nRun Time & Usage\nView run times to track usage and cut down on energy consumption.\nSimple Setup",
#    'postPurchaseWhatsInTheBox_MP_feature_div': "What's in the box\n(1) Smart Wi-Fi Plug Mini EP10",
#    'productDocuments_feature_div': 'Product guides and documents\nSpecification Sheet (PDF)\nUser Guide (PDF)'},
#   'images': ['https://m.media-amazon.com/images/I/61mNHFdgj3L._SX522_.jpg',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
# ...
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/a4d6a923-a790-4a81-b612-8a42ab7ae48f.__CR0,0,150,300_PT0_SX150_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/17b68122-cba4-4f93-a562-90698f72ddba.__CR0,0,150,300_PT0_SX150_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/5a9a59cb-7d46-47e2-8571-a5955953819d.__CR0,0,150,300_PT0_SX150_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/46b32681-01d4-41d4-80c5-f59203c6ccda.__CR0,0,150,300_PT0_SX150_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/17bc022f-a689-4c6f-a177-98345ee6aad2.__CR0,0,150,300_PT0_SX150_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/87bdeca1-123d-49e1-bee2-f06882c75777.__CR0,0,150,300_PT0_SX150_V1___.jpg']},
#  'Meross Matter Smart Plug Mini, Easy Setup, 100% Privacy Smart Outlet, Compact Size, Support Apple Home, Alexa, Google Home with Schedule and Timer, App and Voice Control, 2.4G Wi-Fi Only (2 Pack)': {'data': {'product_title': 'Meross Matter Smart Plug Mini, Easy Setup, 100% Privacy Smart Outlet, Compact Size, Support Apple Home, Alexa, Google Home with Schedule and Timer, App and Voice Control, 2.4G Wi-Fi Only (2 Pack)',
#    'product_brand': 'Visit the meross Store',
#    'product_brand_url': 'https://www.amazon.com/stores/meross/page/6BD28492-A54E-43B5-9D93-223D2E453680?ref_=ast_bln',
#    'product_overview': {'Brand': 'meross',
#     'Material': 'Polycarbonate (PC)',
#     'Connector Type': 'Plug in',
#     'No. of wires': '3',
#     'Plug Format': 'Type B'},
#    'product_about': 'Matter Multi-platform CompatibilityDiscover the power of Matter! Never limited to any platform anymore. Matter plug works seamlessly across all certified smart home platforms such as Apple Home, Alexa, Google Home, and SmartThings, enabling interoperability of all platforms and all Matter products. Note: not support ThreadThe Meross Matter Smart Plug only works with a 2.4Ghz WiFi connection and does [not support Thread protocol]. 100% Privacy & LAN & No CloudEnjoy ultimate privacy with Meross Matter smart plug. No cloud, no registration, and no data tracking. Experience direct access without relying on cloud. With Matter-certified devices on your local area network (LAN), enjoy continuous access even if your home internet goes offline. Customizable Schedules & TimerEfficiently manage your devices with personalized schedules using the timer function. Set specific times for your smart devices to turn on or off, optimizing energy consumption. Perfect for controlling your TV, outdoor lamp, fan, humidifier, blenders, and more. App & Voice ControlMakes controlling appliances a breeze! Manage your smart plug seamlessly through the Meross app or simply use your voice with HomeKit, Google Assistant, or Alexa. Easily turn on and off your appliances and more with just a simple voice command. Super Easy SetupWith Bluetooth on, scan the code and everything is done! The standardized and simple protocol makes it easy to implement and use Matter devices. lt requires an existing 2.4GHz Wi-Fi network and a smartphone running iOS 16.1 or later or Android 8.1 or higher. *The Tuya app on Android does not support Matter at the moment; NOT support Thread protocol. Fire Retardant & Compact DesignAvoid blocking additional cord outlets with its compact design. Crafted with fire-retardant materials, and provides protection against short-circuits and overloads, ensuring your home safety.',
#    'bundleV2_feature_div': 'Make it a bundle\nWe found 1 bundle with this item:\nMeross Matter Smart Plug Mini, Easy Setup, 100% Privacy Smart Outlet, Compact Size, Support A…\nMeross Smart Thermostat for Electric Baseboard & Matter…\n$128\n23\n$134.98\nThis bundle contains 2 items',
#    'detailBullets_feature_div': 'Product details\nPackage Dimensions : 3.98 x 2.24 x 2.17 inches; 4.66 Ounces\nItem model number : MSS115\nDate First Available : January 5, 2023\nManufacturer : meross\nASIN : B0BRQ5ZGKZ\nBest Sellers Rank: #5,353 in Tools & Home Improvement (See Top 100 in Tools & Home Improvement)\n#88 in Electrical Outlet Switches\nCustomer Reviews:\n4.2\n694 ratings',
#    'importantInformation_feature_div': 'Important information\nTo report an issue with this product, click here.',
#    'aplusBrandStory_feature_div': 'From the brand\nSmart Plugs from Meross\nMore Meross Products',
#    'aplus_feature_div': {'': 'Matter Smart Plug Mini',
#     'Multi-Platform Compatibility': '✔',
#     'Matter Multi-Admin': '✔',
#     'Works with HomeKit': '✔',
#     'Super Fast Local Control': '✔',
#     'Offline Control': '✔'},
#    'postPurchaseWhatsInTheBox_MP_feature_div': "What's in the box\n2 x Matter Smart Plug Mini, 1 x User Manual",
#    'productDocuments_feature_div': 'Product guides and documents\nUser Manual (PDF)'},
#   'images': ['https://m.media-amazon.com/images/I/51u0-9VQ33L._SX522_.jpg',
#    'https://m.media-amazon.com/images/I/31gxsSu8zFL._SS250_.jpg',
#    'https://m.media-amazon.com/images/I/31UQ4rR-+tL._SS150_.jpg',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/3583dfe7-0f8d-46c9-8e86-96774d621488.__CR0,0,1464,600_PT0_SX1464_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/61017b03-b40e-43c0-85dd-9d3802e86a4d.__CR0,0,1464,600_PT0_SX1464_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/452833dc-8794-4319-a4af-e38c7d82ca43.__CR0,0,1464,600_PT0_SX1464_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/583e8871-cf22-4902-9b2e-84d645936fbb.__CR0,0,1464,600_PT0_SX1464_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/18a5630e-daa4-44b3-b7a0-8413e8b0a785.__CR0,0,1464,600_PT0_SX1464_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/7b96052a-e192-43a0-a79e-934557eeb523.__CR0,0,1464,600_PT0_SX1464_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/dcf588d7-3af2-44d1-a911-7eeaad62857d.__CR0,0,1464,600_PT0_SX1464_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/b321c2c6-3468-4150-b3af-67074a8910e2.__CR0,0,1464,600_PT0_SX1464_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/a3b56f68-d542-4790-b9b8-f8bb7a5b25db.__CR0,0,1464,600_PT0_SX1464_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/c50d635a-7b67-41b1-b37a-7060cb2feff1.__CR0,0,1464,600_PT0_SX1464_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/e25d4dab-c62a-4ecf-a0e6-1a108b6954ea.__CR0,0,1464,600_PT0_SX1464_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/f06f95ab-ec7a-4c67-9953-93fe67f4af32.__CR0,0,1464,600_PT0_SX1464_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/6de39f5b-6abf-4342-94bf-2a0abff96271.__CR0,0,1464,600_PT0_SX1464_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/6c451a83-1f6a-427c-83e8-339ba1fa4271.__CR0,0,200,225_PT0_SX200_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/e679a8c8-3233-4694-80c4-1dae5c63330d.__CR0,0,200,225_PT0_SX200_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/0d72f295-5ae6-468f-b6dd-cc8f3300b5cb.__CR0,0,200,225_PT0_SX200_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/2f73f754-b2a9-47cf-b5b9-f39af6656dfb.__CR0,0,200,225_PT0_SX200_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/89d57197-f991-4d13-a6b9-52451fe89b57.__CR0,0,800,900_PT0_SX200_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/d85d4bcf-eba0-4cdb-a408-9cebf713ea76.__CR0,0,800,900_PT0_SX200_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/7f255dd5-070c-43c4-b556-47f26a09e6a9.__CR0,0,800,900_PT0_SX200_V1___.jpg']},
#  'HBN Smart Plug 15A, WiFi&Bluetooth Outlet Extender Dual Socket Plugs Works with Alexa, Google Home Assistant, Remote Control with Timer Function, No Hub Required, ETL Certified, 2.4G WiFi Only, 2-Pack': {'data': {'product_title': 'HBN Smart Plug 15A, WiFi&Bluetooth Outlet Extender Dual Socket Plugs Works with Alexa, Google Home Assistant, Remote Control with Timer Function, No Hub Required, ETL Certified, 2.4G WiFi Only, 2-Pack',
#    'product_brand': 'Visit the HBN Store',
#    'product_brand_url': 'https://www.amazon.com/stores/HBN/page/DA1D3526-5E59-4AB9-8CF1-6A3CF75F9D08?ref_=ast_bln',
#    'product_overview': {'Brand': 'HBN',
#     'Color': 'White',
#     'Voltage': '125 Volts',
#     'Product Dimensions': '1.76"D x 4.41"W x 2.11"H',
#     'Material': 'Polycarbonate (PC)'},
#    'product_about': 'CONTROL FROM ANYWHERE - Turn lights, fans, and appliances on or off automatically from anywhere in the world with your smartphone anytime via the HBN Smart app. DUAL PLUG & INDEPENDENT CONTROL - HBN smart plugs with two grounded outlets (up to 15A, 1875w) feature space-saving for users, which can control all electrical appliances individually or together. VOICE CONTROL - Simply voice command to control multiple home devices with our smart outlet via Alexa or Google Home. Enjoy the hands-free convenience of controlling any home electronic appliances. Made for everyone, Perfect for elderly, disabled or if the plug is hard-to-reach. TIMER AND SCHEDULE SETTING- Use timer or countdown schedules to automatically turn on and off any home electronics and appliances such as lamps, fans, humidifier, Christmas lights etc. For example, setting lights to come on at dusk or turning off at sunrise to reduce energy consumption and save money. EASY TO INSTALL & WARRANTY - Download the HBN Smart App and follow the instructions to connect the smart plugs. No Hub Required, works with 2.4GHz network. ETL certified for safety use. 15 months warranty.',
#    'detailBullets_feature_div': 'Product details\nProduct Dimensions : 4.41 x 2.11 x 1.76 inches; 7.83 Ounces\nItem model number : U153T\nDate First Available : September 17, 2019\nManufacturer : HBN\nASIN : B07XZJ412P\nBest Sellers Rank: #1,512 in Tools & Home Improvement (See Top 100 in Tools & Home Improvement)\n#44 in Electrical Outlet Switches\nCustomer Reviews:\n4.3\n3,238 ratings',
#    'importantInformation_feature_div': 'Important information\nTo report an issue with this product, click here.',
#    'aplusBrandStory_feature_div': "From the brand\nAbout HBN: A direct distributor of premium quality home improvement products. We strive to provide better products and after-sales service to help every customer's life easier and more convenient.\nOur Products: indoor & outdoor smart plug, remote outlet, mini fridge and string lights.\nOutdoor remote outlet\nVisit the Store\nHeavy Duty 3-Prong Outlet\nVisit the Store",
#    'aplus_feature_div': {'': 'HBN WiFi Dual Smart Plug',
#     'Compatible with Alexa': '✓',
#     'Work with Google Assistant': '✓',
#     'Indoor/Outdoor': 'Indoor',
#     'Number of Outlets': '2',
#     'Voice Control': '✓',
#     'Plug In/In-Wall': 'Plug In',
#     'Individual Control': '✓'},
#    'postPurchaseWhatsInTheBox_MP_feature_div': "What's in the box\nsmart plug",
#    'productDocuments_feature_div': 'Product guides and documents\nApplication Guide (PDF)\nUser Manual (PDF)'},
#   'images': ['https://m.media-amazon.com/images/I/51mDBFN8wML._SX522_.jpg',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/93b7c7b7-8887-4dea-959e-6b720f6fcbd5.__CR0,0,200,225_PT0_SX200_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/722a7542-4ffd-4881-988f-c62d29c81943.__CR0,0,200,225_PT0_SX200_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/696891db-6e46-4a57-b2e6-4ef5429004ac.__CR0,0,200,225_PT0_SX200_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/181ebe76-0d0e-4c26-9ce7-7604dfe364db.__CR0,0,200,225_PT0_SX200_V1___.jpg',
#    'https://m.media-amazon.com/images/S/aplus-media-library-service-media/522a2484-25da-4c33-9c75-034fd0a7d3fb.__CR0,0,200,225_PT0_SX200_V1___.jpg']}}

# %%
product_details['Kasa Smart Plug HS103P4, Smart Home Wi-Fi Outlet Works with Alexa, Echo, Google Home & IFTTT, No Hub Required, Remote Control, 15 Amp, UL Certified, 4-Pack, White']
# Out:
# {'data': {'product_title': 'Kasa Smart Plug HS103P4, Smart Home Wi-Fi Outlet Works with Alexa, Echo, Google Home & IFTTT, No Hub Required, Remote Control, 15 Amp, UL Certified, 4-Pack, White',
#   'product_brand': 'Visit the Kasa Smart Store',
#   'product_brand_url': 'https://www.amazon.com/stores/KasaSmartbyTP-Link/page/9A672382-E380-4360-A698-DFBEAE7E7049?ref_=ast_bln',
#   'product_overview': {'Brand': 'Kasa Smart',
#    'Color': 'Indoor Plug 4-Pack',
#    'Connector Type': 'Plug in',
#    'No. of wires': '3',
#    'Plug Format': 'Type B'},
#   'product_about': 'Voice control: Kasa smart plugs that work with Alexa and Google Home Assistant. Enjoy the hands free convenience of controlling any home electronic appliances with your voice via Amazon Alexa or Google Assistant. Compatible with Android 5.0 or higher and iOS 10.0 or higher Smart Outlet Control from anywhere: Turn electronics on and off your smart home devices from anywhere with your smartphone using the Kasa app, whether you are at home, in the office or on vacation Scheduling: Use timer or countdown schedules to set your wifi smart plug to automatically turn on and off any home electronic appliances such as lamps, fan, humidifier, Christmas lights etc. The Kasa app is free and compatible with iOS 10.0 or later. Easy set up and use: 2.4GHz Wi-Fi connection required. Plug in, open the Kasa app, follow the simple instructions and enjoy Trusted and reliable: Designed and developed in Silicon Valley, Kasa is trusted by over 5 Million users and being the readers choice for PCMag 2020. UL certified for safety use.',
#   'aplusBrandStory_feature_div': 'From the brand\nLeading Smart Home Brand\nLaunched in 2015, Kasa Smart quickly became a leading smart home brand giving convenience, fun, and security to over 7 million delighted users and has garnered praises from PCMag, Wirecutter, and more. Users can control their lights, appliances, and view security camera footage from anywhere, anytime. Kasa offers terrific synergy between devices for enhanced automation.\nKasa Best Sellers\nVisit the Store\nSmart Wi-Fi Plugs\nVisit the Store',
#   'aplus_feature_div': "From the manufacturer\nVoice Control\nFree up your hands by using simple voice commands with Alexa and Google Assistant.\nVoice Control Control from Anywhere Grouping\nSmart Actions\nCreate interactions with your plug and other Kasa products. Connect a lamp to your plug so that when your camera detects motion, your light turns on.\nApp Features\nScheduling\nSchedule your connected devices to turn on and off automatically at specified times.\nCount Down Timer\nSet a timer for your connected appliance to automatically turn off when the time runs out.\nAway Mode\nAway Mode will automatically turn on and off connected appliances, like lamps, to make it appear as if you're home.\nRun Time & Usage\nView run times to track usage and cut down on energy consumption.\nSimple Setup",
#   'productDescription-3_feature_div': 'Product Description\nThe HS103 Kasa smart plug is the easiest way you can start controlling lamps, fans, humidifiers and other home electronic appliances. With it adding voice control to any outlet, you could also enjoy the hands-free convenience. The Kasa app contains not only all the feature you expect from TP-Link Kasa family, but also guidance for you through each step of the installation to connect your smart plug with your home Wi-Fi, Alexa or Google assistant.',
#   'productDetailsNonPets_feature_div': {'Manufacturer': 'TP-Link',
#    'Part Number': 'HS103P4',
#    'Item Weight': '4 ounces',
#    'Product Dimensions': '1.57 x 1.5 x 2.62 inches',
#    'Country of Origin': 'Vietnam',
#    'Item model number': 'HS103P4',
#    'Size': '4 Count (Pack of 1)',
#    'Color': 'Indoor Plug 4-Pack',
#    'Style': 'Mini 4-Pack',
#    'Pattern': 'WiFi Outlet',
#    'Power Source': 'Corded Electric',
#    'Item Package Quantity': '1',
#    'Number Of Pieces': '4',
#    'Measurement Accuracy': '0.1',
#    'Mounting Type': 'Plug-In Mount',
#    'Plug Format': 'Type B',
#    'Included Components': 'HS103 Smart Wi-Fi Plug Lite (4)',
#    'Batteries Included?': 'No',
#    'Batteries Required?': 'No',
#    'Warranty Description': '2 year manufacturer'},
#   'productDocuments-2_feature_div': 'Product guides and documents\nSpecification Sheet (PDF)\nUser Guide (PDF)',
#   'importantInformation_feature_div': 'Important information\nTo report an issue with this product, click here.'},
#  'images': ['https://m.media-amazon.com/images/I/51zoLDBO0wL._AC_SX679_PIbundle-4,TopRight,0,0_SH20_.jpg',
#   'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#   'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#   'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#   'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#   'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#   'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#   'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#   'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#   'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#   'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#   'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#   'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#   'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#   'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#   'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#   'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#   'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#   'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#   'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#   'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#   'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#   'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#   'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#   'https://m.media-amazon.com/images/S/aplus-media/vc/1eb0cd16-37c1-4f9a-bb5e-ded526dbe7b2.__CR0,0,1464,600_PT0_SX1464_V1___.png',
#   'https://m.media-amazon.com/images/S/aplus-media/vc/688e4663-2901-4dcb-b024-63703ec7723e.__CR0,0,1464,600_PT0_SX1464_V1___.png',
#   'https://m.media-amazon.com/images/S/aplus-media/vc/e599bb1d-b81c-48d4-b136-531e3a31c2f6.__CR0,0,1464,600_PT0_SX1464_V1___.png',
#   'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#   'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#   'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#   'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#   'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#   'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#   'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#   'https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/grey-pixel.gif',
#   'https://m.media-amazon.com/images/I/41JnNfpIRXL._SS75_.jpg']}
